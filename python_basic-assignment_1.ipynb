# %% [raw]
# #question1
# expressions:    * ; - ; / ; +
# values:         "hello";-87.8;6

# %% [raw]
# #question2
#
# variables- the name assignted to a memory space which holds the data assigned to it. This data can be accessed and manipulated by using this variable.
#
# string - a series of characters that are stored between single or double quotes.

# %% [raw]
# #question3
#     int - it is used to store an interger variable.
#     float-it is used to store an number with decimal digits.
#     boolean - this is a data type that represents only one of two values, true and false.

# %% [raw]
# #question4
# a series of compatible variables and constants that are joined by different operators which when executed give logical output.

# %% [raw]
# #question5
# statements are usually related to assignment, reading inputs and displaying outputs. Expressions is a combination of operators, variables and constants that yeild a result.

# %% [raw]
# #question6
# bacon =22
# bacon+1
#
# #output =23

# %% [raw]
# #question7
# "spam"+"spamspam"
# #output "spamspamspam"
#
# "spam"*3
# #output "spamspamspam"

# %% [raw]
# #question8
# a series of characters is not considered a string unless it is enclosed in a pair of single quotes or double quotes. Hence eggs can be a variable but not "eggs". there is no such clear distinction we can make in order to use numerical values as variables, they will be considered as constants in expressions

# %% [raw]
# #question9
# int()
# float()
# str()
# these expressions are used the respective version of the value entered in the
# braces

# %% [raw]
# #question10
# "i have eaten "+99+"burritos"
# this statement gives an error because concatenation can occur only between #the string and not strings and integers
# this error can be rectified if we typecast the 99 to string datatype
#
# "i have eaten "+str(99)+" burritos."
